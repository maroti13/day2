# %% [markdown]
# List_Comprehension

# %%
numbers=[11,22,3,4,5,66,7]
numbers
# Out:
# [11, 22, 3, 4, 5, 66, 7]

# %%
new_numbers=[]
for i in numbers:
    new_numbers.append(i*2)
print(new_numbers)
# Out:
# [22, 44, 6, 8, 10, 132, 14]

# %% [markdown]
# Lamda function in pyton

# %%
def raise_to_the_power_of(x):
    return x **2

# %%
raise_to_the_power_of(20)
# Out:
# 400

# %%
lambda x:x**2
# Out:
# <function __main__.<lambda>(x)>

# %%
(lambda x:x/5)(10)
# Out:
# 2.0

# %% [markdown]
# sum_xy=lambda x,y:x+y
# sum=xy(2,3)

# %%
sum_xy=lambda x,y:x+y
sum_xy(9,0)
# Out:
# 9

# %%
def multiply_by_10(x):
    return x*10

# %%
multiply_by_10(5)
# Out:
# 50

# %%
import requests

# %%
response=request.get("https://api.frankfurter.dev/v1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 response=request.get("https://api.frankfurter.dev/v1")
#
# NameError: name 'request' is not defined

# %%
response.status_code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 response.status_code
#
# NameError: name 'response' is not defined

# %% [raw]
# import json

# %%
json.dumps(response.json(),indent=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 json.dumps(response.json(),indent=4)
#
# NameError: name 'response' is not defined

# %%
base_site= "https://itunes.apple.com/search"
