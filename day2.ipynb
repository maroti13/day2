# %%
a=10
b=2
c=a+b
print(c)
# Out:
# 12

# %%
# !git init
# Out:
# Initialized empty Git repository in C:/Users/marot/anaconda_projects/e9dbe134-1921-4c6e-bafc-348e5ddc592b/.git/

# %%
# !git add day2.ipynb

# %%
# !git commit -m "This is my day 2  of learning python"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git remote add origin https://github.com/maroti13/day2.git

# %%
# !git branch -m main

# %%
# !git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# Everything up-to-date

# %%
a*=3

# %%
b+=3

# %%
b
# Out:
# 5

# %%
x=4
y=3

# %%
y<x and x<5
# Out:
# True

# %%
oct(3)
# Out:
# '0o3'

# %% [markdown]
# # this is gonna about bitwise operator like or,and,xor,xnor,leftshift and rightshift
