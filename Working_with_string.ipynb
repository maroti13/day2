# %% [markdown]
# # String's operation will be below

# %%
'naven' * 10
# Out:
# 'navennavennavennavennavennavennavennavennavennaven'

# %%
text='Maroti'

# %%
print(text[:3])
# Out:
# Mar

# %%
print(text[0])
# Out:
# M

# %% [markdown]
# # LIST

# %%
num=[11,22,33,44,55]

# %%
print(num)
# Out:
# [11, 22, 33, 44, 55]

# %%
num[3]
# Out:
# 44

# %%
num[2:4]
# Out:
# [33, 44]

# %%
num.append(19)

# %%
num
# Out:
# [11, 22, 33, 44, 55, 19]

# %%
num.pop()
# Out:
# 19
